# %% [markdown]
# # Assignment 1: Weather Agent Debugging & Testing
#
# This notebook demonstrates the fully functional weather agent.

# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'weather_agent'))

from weather_agent.graph import weather_agent

state = {
    "name": "Test User",
    "location_data": None,
    "weather_data": None,
    "weather_info": None,
}

final_state = weather_agent.invoke(state)

print("\n" + "=" * 60)
print("WEATHER INFORMATION")
print("=" * 60)
print(final_state.get("weather_info", "No info available."))
